# %% [markdown]
# # TP – Suites numériques, limites et récurrence
# **Niveau : Terminale – Spécialité Maths**
# **Professeur : M. BENKASSOU BADR**

# %% [markdown]
# ## ✦ Exercice 1 – Abonnés d’une salle de sport
# Une salle de sport a ouvert en **2019** et **3 500** personnes se sont inscrites dès la première année.
# Chaque année, **80 %** des inscrits renouvellent leur abonnement et **450** nouvelles inscriptions sont enregistrées.
#
# On note $a_n$ le nombre d’abonnés au cours de l’année **2019 + n**, donc $a_0 = 3500$.

# %% [markdown]
# ### 1) Relation de récurrence
# Exprimer $a_{n+1}$ en fonction de $a_n$.

# %% [markdown]
# ### 2) Fonction récurrente
# Écrire une fonction Python `abonnes(n)` qui renvoie $a_n$ (forme récurrente).

# %%
def abonnes(n):
    """Calcule a_n par récurrence"""
    u = ...                 
    for k in range(...):    
        u = ...             
    return ...

# %%
# 🔎 Test de la fonction abonnes
print("a_0 attendu: 3500 →", abonnes(0))
print("a_1 →", abonnes(1))
print("a_11 →", abonnes(11))

# %% [markdown]
# ### 3) Suite auxiliaire
# On pose $b_n = a_n - 2250$.
# 1. Montrer que la suite $(b_n)$ est géométrique de raison 0,8 et préciser $b_0$.
# 2. Écrire une fonction Python `auxiliaire(n)` qui calcule $b_n$ .

# %%
def auxiliaire(n):
    """Calcule b_n par récurrence"""
    v = ...                 # b_0
    for k in range(...):    
        v = ...             
    return v

# %%
# 🔎 Test de la fonction auxiliaire
print("b_0 →", auxiliaire(0))
print("b_1 →", auxiliaire(1))
print("b_2 →", auxiliaire(2))

# %% [markdown]
# 3. Démontrer que $b_n = 1250 \times 0.8^n$.
# 4. En déduire que $a_n = 1250 \times 0.8^n + 2250$.
# 5. Écrire une fonction Python `abonnes2(n)` qui calcule $a_n$ (forme explicite).

# %%
def abonnes2(n):
    """Calcule a_n par la formule explicite"""
    return ...              # compléter avec la formule explicite

# %%
# 🔎 Test de la fonction abonnes2
print("a_0 →", abonnes2(0))
print("a_1 →", abonnes2(1))
print("a_11 →", abonnes2(11))

# %% [markdown]
# ### 4) Liste des abonnés
# Écrire une fonction Python `list_abonnes(n)` qui renvoie la liste `[a_0, a_1, ..., a_n]`.

# %%
def list_abonnes(n):
    """Renvoie la liste des nombres d'abonnés de 2019 à 2019+n"""
    L = []
    for k in range(...):      # compléter
        L.append(...)         # compléter
    return L

# %%
# 🔎 Test de la fonction list_abonnes
print("Liste jusqu'à n=5 →", list_abonnes(5))

# %% [markdown]
# ### 5) Limite et seuil
# 1. Déterminer $\lim_{n\to+\infty} a_n$ et interpréter le résultat.
# 2. Écrire une fonction Python `seuil(p)` qui calcule le plus petit rang $n_0$ tel que $|a_n - 2250| < 10^{-p}$.

# %%
def seuil(p):
    """Renvoie le plus petit rang n0 tel que |a_n - 2250| < 10^{-p}"""
    n = ...
    while ...:                # compléter la condition d'arrêt
        n = ...
    return ...

# %%
# 🔎 Test de la fonction seuil
print("Seuil pour p=2 →", seuil(2))

# %% [markdown]
# ---
# ## ✦ Exercice 2 – Croissance d’un bambou
# Un infographiste simule la croissance d’un bambou.
# On considère un bambou de **taille initiale 1 m** ($u_0 = 100$ cm).
# Chaque mois, sa taille augmente de **5 %** de la taille du mois précédent et on ajoute **20 cm**.
#
# On note $u_n$ la taille (en cm) à la fin du $n$-ième mois.

# %% [markdown]
# ### 1) Calcul direct
# Calculer $u_1$ et $u_2$ sachant que :
# $$
# u_{n+1} = 1.05\,u_n + 20
# $$

# %% [markdown]
# ### 2) Fonction récurrente
# Écrire une fonction Python `taille(n)` qui renvoie $u_n$.

# %%
def taille(n):
    """Renvoie la taille du bambou en cm au bout de n mois"""
    u = 100                   # taille initiale en cm
    for k in range(...):      # compléter
        u = ...               # compléter 
    return u

# %%
# 🔎 Test de la fonction taille
print("Taille après 1 mois →", taille(1))
print("Taille après 2 mois →", taille(2))
print("Taille après 7 mois →", taille(7))

# %% [markdown]
# ### 4) Seuil de 2 m
# On souhaite connaître le **nombre de mois** nécessaire pour que le bambou dépasse **2 m (200 cm)**.
# Compléter le script suivant :

# %%
def taille2():
    """Détermine le nombre de mois pour que le bambou dépasse 2 m"""
    u = 100
    n = 0
    while ...:               # compléter 
        u = ...              # compléter 
        n = n + 1
    return n

# %%
# 🔎 Test de la fonction taille2
print("Nombre de mois pour dépasser 2 m →", taille2())

# %% [markdown]
# ### 5) Bambou de 50 cm atteignant 10 m
# On considère maintenant un bambou de **50 cm** au départ.
# On veut savoir combien de mois sont nécessaires pour qu’il atteigne ou dépasse **10 m (1000 cm)**.
# Compléter le script ci-dessous :

# %%
def taille3():
    """Renvoie le nombre de mois pour qu’un bambou de 50 cm atteigne ou dépasse 10 m"""
    u = ...                  # compléter la taille initiale
    n = 0
    while ...:               # compléter la condition d'arrêt 
        u = ...              # compléter 
        n = n + 1
    return n

# %%
# 🔎 Test de la fonction taille3
print("Nombre de mois pour un bambou de 50 cm →", taille3())
